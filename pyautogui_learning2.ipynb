# %%
import pyautogui as pt
import webbrowser
import time

# %%
url = "https://app.powerbi.com/groups/me/apps/62a2c8f6-a529-4b77-87b6-1676d50e4d56/reports/21d21bbd-bde2-4e5c-8d3e-5f570a6040e6?experience=power-bi"
webbrowser.open(url)

test = "no"
while test == "no":    
    try:
        x, y = pt.locateCenterOnScreen("m_mfr.png", confidence=0.8)
    except:
        x = "no_img"

    if x != "no_img":    
        test = "yes"


test = "no"
while test == "no":    
    try:
        x, y = pt.locateCenterOnScreen("m_p&l.png", confidence=0.8)
    except:
        x = "no_img"

    if x != "no_img":    
        pt.moveTo(x,y,1)
        pt.leftClick()
        test = "yes"

test = "no"
while test == "no":    
    try:
        x, y = pt.locateCenterOnScreen("m_p&l_glance.png", confidence=0.8)
    except:
        x = "no_img"

    if x != "no_img":    
        pt.moveTo(x,y,1)
        pt.leftClick()
        test = "yes"

time.sleep(1)
pt.moveTo(1507, 838,1)
pt.leftClick()

test = "no"
while test == "no":    
    try:
        x, y = pt.locateCenterOnScreen("m_option1.png", confidence=0.8)
    except:
        x = "no_img"

    if x != "no_img":    
        pt.moveTo(x+40,y,1)
        pt.leftClick()
        test = "yes"


test = "no"
while test == "no":    
    try:
        x, y = pt.locateCenterOnScreen("m_export.png", confidence=0.8)
    except:
        x = "no_img"

    if x != "no_img":    
        pt.moveTo(x+40,y,1)
        pt.leftClick()
        test = "yes"

test = "no"
while test == "no":    
    try:
        x, y = pt.locateCenterOnScreen("m_export2.png", confidence=0.8)
    except:
        x = "no_img"

    if x != "no_img":    
        pt.moveTo(x+40,y,1)
        pt.leftClick()
        test = "yes"

# %%
time.sleep(3)
pt.moveTo(1647+40,405,2)

# %%
test = pt.prompt(text="",title="test")

url = "https://app.powerbi.com/groups/me/apps/62a2c8f6-a529-4b77-87b6-1676d50e4d56/reports/21d21bbd-bde2-4e5c-8d3e-5f570a6040e6?experience=power-bi"
webbrowser.open(url)

time.sleep(1)
location = pt.locateCenterOnScreen("mfr.PNG", confidence=0.8)
while location == None:
    time.sleep(1)
    location = pt.locateCenterOnScreen("mfr.PNG", confidence=0.8)



time.sleep(1)
location = pt.locateCenterOnScreen("pl.PNG", confidence=0.8)
while location == None:
    time.sleep(1)
    location = pt.locateCenterOnScreen("pl.PNG", confidence=0.8)
    if location == None:
        pt.moveTo(151,521,1)
        pt.scroll(-100)


pt.moveTo(location,duration=1)
pt.click()
time.sleep(1)


time.sleep(1)
b_select = pt.locateCenterOnScreen("2019.PNG",confidence=0.7)
while b_select == None:
    time.sleep(1)
    b_select = pt.locateCenterOnScreen("2019.PNG",confidence=0.7)


if b_select != None:
    pt.moveTo(b_select,duration=1)
    pt.click()


time.sleep(1)
b_select = pt.locateCenterOnScreen("title.PNG",confidence=0.7)
while b_select == None:
    time.sleep(1)
    b_select = pt.locateCenterOnScreen("title.PNG",confidence=0.7)

time.sleep(4)

time.sleep(1)
b_select = pt.locateCenterOnScreen("b_mth.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()

time.sleep(1)
b_select = pt.locateCenterOnScreen("b_qtd.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()


time.sleep(1)
b_select = pt.locateCenterOnScreen("b_qtract.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()


time.sleep(1)
b_select = pt.locateCenterOnScreen("b_ytd.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()

time.sleep(1)
b_select = pt.locateCenterOnScreen("b_qtrfc.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()



time.sleep(1)
b_select = pt.locateCenterOnScreen("b_qtrtogo.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()


time.sleep(1)
b_select = pt.locateCenterOnScreen("b_togo.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()

time.sleep(1)
b_select = pt.locateCenterOnScreen("b_fy.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()


# MTH


time.sleep(1)
b_select = pt.locateCenterOnScreen("w_mth.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()

time.sleep(1)
export = pt.locateCenterOnScreen("export.PNG",confidence=0.7)
pt.moveTo(export,duration=1)
pt.click()

time.sleep(1)
powerpoint = pt.locateCenterOnScreen("powerpoint.PNG",confidence=0.7)
if powerpoint != None:
    pt.moveTo(powerpoint,duration=1)

time.sleep(1)
embed_image = pt.locateCenterOnScreen("embed an image.PNG",confidence=0.7)
if embed_image != None:
    pt.moveTo(embed_image,duration=1)
    pt.click()


time.sleep(1)
current_page = pt.locateCenterOnScreen("current page.PNG",confidence=0.7)
if current_page != None:
    pt.moveTo(current_page,duration=1)
    pt.click()


time.sleep(1)
f_export = pt.locateCenterOnScreen("f_export.PNG",confidence=0.7)
if f_export != None:
    pt.moveTo(f_export)
    pt.click()

time.sleep(50)


time.sleep(1)
b_select = pt.locateCenterOnScreen("b_mth.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()

#-------------------------------------

# QTR

time.sleep(1)
b_select = pt.locateCenterOnScreen("w_qtd.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()

time.sleep(1)
export = pt.locateCenterOnScreen("export.PNG",confidence=0.7)
pt.moveTo(export,duration=1)
pt.click()

time.sleep(1)
powerpoint = pt.locateCenterOnScreen("powerpoint.PNG",confidence=0.7)
if powerpoint != None:
    pt.moveTo(powerpoint,duration=1)

time.sleep(1)
embed_image = pt.locateCenterOnScreen("embed an image.PNG",confidence=0.7)
if embed_image != None:
    pt.moveTo(embed_image,duration=1)
    pt.click()


time.sleep(1)
current_page = pt.locateCenterOnScreen("current page.PNG",confidence=0.7)
if current_page != None:
    pt.moveTo(current_page,duration=1)
    pt.click()


time.sleep(1)
f_export = pt.locateCenterOnScreen("f_export.PNG",confidence=0.7)
if f_export != None:
    pt.moveTo(f_export)
    pt.click()

time.sleep(50)


time.sleep(1)
b_select = pt.locateCenterOnScreen("b_qtd.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()

#---------------------------------------

'''
# YTD

time.sleep(1)
b_select = pt.locateCenterOnScreen("w_ytd.PNG",confidence=0.8)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()

time.sleep(1)
export = pt.locateCenterOnScreen("export.PNG",confidence=0.7)
pt.moveTo(export,duration=1)
pt.click()

time.sleep(1)
powerpoint = pt.locateCenterOnScreen("powerpoint.PNG",confidence=0.7)
if powerpoint != None:
    pt.moveTo(powerpoint,duration=1)

time.sleep(1)
embed_image = pt.locateCenterOnScreen("embed an image.PNG",confidence=0.7)
if embed_image != None:
    pt.moveTo(embed_image,duration=1)
    pt.click()


time.sleep(1)
current_page = pt.locateCenterOnScreen("current page.PNG",confidence=0.7)
if current_page != None:
    pt.moveTo(current_page,duration=1)
    pt.click()


time.sleep(1)
f_export = pt.locateCenterOnScreen("f_export.PNG",confidence=0.7)
if f_export != None:
    pt.moveTo(f_export)
    pt.click()

time.sleep(50)


time.sleep(1)
b_select = pt.locateCenterOnScreen("b_ytd.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()

'''
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# c:\Users\purusp\OneDrive - adidas\Adidas\2025\1. Projects\3. REPORTING\python_board_report\pyautogui_learning2.ipynb Cell 2 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/purusp/OneDrive%20-%20adidas/Adidas/2025/1.%20Projects/3.%20REPORTING/python_board_report/pyautogui_learning2.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> webbrowser.open(url)
#       <a href='vscode-notebook-cell:/c%3A/Users/purusp/OneDrive%20-%20adidas/Adidas/2025/1.%20Projects/3.%20REPORTING/python_board_report/pyautogui_learning2.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> time.sleep(1)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/purusp/OneDrive%20-%20adidas/Adidas/2025/1.%20Projects/3.%20REPORTING/python_board_report/pyautogui_learning2.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a> location = pt.locateCenterOnScreen("mfr.PNG", confidence=0.8)
# ...

# %%
test = pt.prompt(text="",title="test")

url = "https://app.powerbi.com/groups/me/apps/62a2c8f6-a529-4b77-87b6-1676d50e4d56/reports/21d21bbd-bde2-4e5c-8d3e-5f570a6040e6?experience=power-bi"
webbrowser.open(url)

time.sleep(15)


time.sleep(1)
location = pt.locateCenterOnScreen("pl.PNG", confidence=0.8)
while location == None:
    time.sleep(1)
    location = pt.locateCenterOnScreen("pl.PNG", confidence=0.8)
    if location == None:
        pt.moveTo(151,521,1)
        pt.scroll(-100)


pt.moveTo(location,duration=1)
pt.click()


time.sleep(1)
pt.moveRel(0,145,1)
pt.click()
time.sleep(1)
pt.click()


time.sleep(5)

b_select = pt.locateCenterOnScreen("b_mth.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()

time.sleep(1)
b_select = pt.locateCenterOnScreen("b_qtract.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()


time.sleep(1)
b_select = pt.locateCenterOnScreen("b_ytd.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()


time.sleep(1)
b_select = pt.locateCenterOnScreen("b_togo.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()

time.sleep(1)
b_select = pt.locateCenterOnScreen("b_fy.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()


time.sleep(1)
b_select = pt.locateCenterOnScreen("b_qtd.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()


time.sleep(1)
b_select = pt.locateCenterOnScreen("b_qtrtogo.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()


time.sleep(1)
b_select = pt.locateCenterOnScreen("b_qtr.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()


# MTH


time.sleep(1)
b_select = pt.locateCenterOnScreen("w_mth.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()

time.sleep(1)
export = pt.locateCenterOnScreen("export.PNG",confidence=0.7)
pt.moveTo(export,duration=1)
pt.click()

time.sleep(1)
powerpoint = pt.locateCenterOnScreen("powerpoint.PNG",confidence=0.7)
if powerpoint != None:
    pt.moveTo(powerpoint,duration=1)

time.sleep(1)
embed_image = pt.locateCenterOnScreen("embed an image.PNG",confidence=0.7)
if embed_image != None:
    pt.moveTo(embed_image,duration=1)
    pt.click()


time.sleep(1)
current_page = pt.locateCenterOnScreen("current page.PNG",confidence=0.7)
if current_page != None:
    pt.moveTo(current_page,duration=1)
    pt.click()


time.sleep(1)
f_export = pt.locateCenterOnScreen("f_export.PNG",confidence=0.7)
if f_export != None:
    pt.moveTo(f_export)
    pt.click()

time.sleep(50)


time.sleep(1)
b_select = pt.locateCenterOnScreen("b_mth.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()

#-------------------------------------

# QTR ACT

time.sleep(1)
b_select = pt.locateCenterOnScreen("w_qtract.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()

time.sleep(1)
export = pt.locateCenterOnScreen("export.PNG",confidence=0.7)
pt.moveTo(export,duration=1)
pt.click()

time.sleep(1)
powerpoint = pt.locateCenterOnScreen("powerpoint.PNG",confidence=0.7)
if powerpoint != None:
    pt.moveTo(powerpoint,duration=1)

time.sleep(1)
embed_image = pt.locateCenterOnScreen("embed an image.PNG",confidence=0.7)
if embed_image != None:
    pt.moveTo(embed_image,duration=1)
    pt.click()


time.sleep(1)
current_page = pt.locateCenterOnScreen("current page.PNG",confidence=0.7)
if current_page != None:
    pt.moveTo(current_page,duration=1)
    pt.click()


time.sleep(1)
f_export = pt.locateCenterOnScreen("f_export.PNG",confidence=0.7)
if f_export != None:
    pt.moveTo(f_export)
    pt.click()

time.sleep(50)


time.sleep(1)
b_select = pt.locateCenterOnScreen("b_qtract.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()

#---------------------------------------

# YTD

time.sleep(1)
b_select = pt.locateCenterOnScreen("w_ytd.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()

time.sleep(1)
export = pt.locateCenterOnScreen("export.PNG",confidence=0.7)
pt.moveTo(export,duration=1)
pt.click()

time.sleep(1)
powerpoint = pt.locateCenterOnScreen("powerpoint.PNG",confidence=0.7)
if powerpoint != None:
    pt.moveTo(powerpoint,duration=1)

time.sleep(1)
embed_image = pt.locateCenterOnScreen("embed an image.PNG",confidence=0.7)
if embed_image != None:
    pt.moveTo(embed_image,duration=1)
    pt.click()


time.sleep(1)
current_page = pt.locateCenterOnScreen("current page.PNG",confidence=0.7)
if current_page != None:
    pt.moveTo(current_page,duration=1)
    pt.click()


time.sleep(1)
f_export = pt.locateCenterOnScreen("f_export.PNG",confidence=0.7)
if f_export != None:
    pt.moveTo(f_export)
    pt.click()

time.sleep(50)


time.sleep(1)
b_select = pt.locateCenterOnScreen("b_ytd.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()

# %%
test = pt.prompt(text="",title="test")

time.sleep(1)
b_select = pt.locateCenterOnScreen("w_mth.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()

time.sleep(1)
export = pt.locateCenterOnScreen("export.PNG",confidence=0.7)
pt.moveTo(export,duration=1)
pt.click()

time.sleep(1)
powerpoint = pt.locateCenterOnScreen("powerpoint.PNG",confidence=0.7)
if powerpoint != None:
    pt.moveTo(powerpoint,duration=1)

time.sleep(1)
embed_image = pt.locateCenterOnScreen("embed an image.PNG",confidence=0.7)
if embed_image != None:
    pt.moveTo(embed_image,duration=1)
    pt.click()


time.sleep(1)
current_page = pt.locateCenterOnScreen("current page.PNG",confidence=0.7)
if current_page != None:
    pt.moveTo(current_page,duration=1)
    pt.click()


time.sleep(1)
f_export = pt.locateCenterOnScreen("f_export.PNG",confidence=0.7)
if f_export != None:
    pt.moveTo(f_export)
    pt.click()

# %%
test = pt.prompt(text="",title="test")

time.sleep(1)
b_select = pt.locateCenterOnScreen("w_mth.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()

time.sleep(1)
export = pt.locateCenterOnScreen("export.PNG",confidence=0.7)
pt.moveTo(export,duration=1)
pt.click()

time.sleep(1)
powerpoint = pt.locateCenterOnScreen("powerpoint.PNG",confidence=0.7)
if powerpoint != None:
    pt.moveTo(powerpoint,duration=1)

time.sleep(1)
embed_image = pt.locateCenterOnScreen("embed an image.PNG",confidence=0.7)
if embed_image != None:
    pt.moveTo(embed_image,duration=1)
    pt.click()


time.sleep(1)
current_page = pt.locateCenterOnScreen("current page.PNG",confidence=0.7)
if current_page != None:
    pt.moveTo(current_page,duration=1)
    pt.click()


time.sleep(1)
f_export = pt.locateCenterOnScreen("f_export.PNG",confidence=0.7)
if f_export != None:
    pt.moveTo(f_export)
    pt.click()


time.sleep(50)


time.sleep(1)
b_select = pt.locateCenterOnScreen("b_mth.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()

# %%
test = pt.prompt(text="",title="test")

time.sleep(1)
download = pt.locateCenterOnScreen("downloaded.PNG",confidence=0.7)
while download == None:
    time.sleep(1)


time.sleep(1)
b_select = pt.locateCenterOnScreen("b_mth.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()

# %%
print(download)
# Out:
# None

# %%
test = pt.prompt(text="",title="test")

time.sleep(4)
b_select = pt.locateCenterOnScreen("b_mth.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()

time.sleep(1)
b_select = pt.locateCenterOnScreen("b_qtract.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()


time.sleep(1)
b_select = pt.locateCenterOnScreen("b_ytd.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()


time.sleep(1)
b_select = pt.locateCenterOnScreen("b_togo.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()

time.sleep(1)
b_select = pt.locateCenterOnScreen("b_fy.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()


time.sleep(1)
b_select = pt.locateCenterOnScreen("b_qtd.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()


time.sleep(1)
b_select = pt.locateCenterOnScreen("b_qtrtogo.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()


time.sleep(1)
b_select = pt.locateCenterOnScreen("b_qtr.PNG",confidence=0.7)
if b_select != None:    
    pt.moveTo(b_select,duration=1)
    pt.click()

# %%
test = pt.prompt(text="",title="test")


time.sleep(1)
pt.moveRel(0,250,1)
pt.click()

# %%
print(export)
# Out:
# Point(x=617, y=219)

# %%
test = pt.prompt(text="",title="test")

url = "https://app.powerbi.com/groups/me/apps/b69dcb06-a0bc-4351-a569-06fa7dc97b0c/reports/11f6330c-9606-4bf9-9a30-a487d5cad3e5/ReportSectioneb6b33940c66bb50974c?experience=power-bi"
webbrowser.open(url)

time.sleep(15)

export = pt.locateCenterOnScreen("export.PNG", confidence=0.8)
while export == None:
    export = pt.locateCenterOnScreen("export.PNG", confidence=0.8)


if export != None:
    time.sleep(1)
    location = pt.locateCenterOnScreen("pl.PNG", confidence=0.8)
    while location == None:
        time.sleep(1)
        location = pt.locateCenterOnScreen("pl.PNG", confidence=0.8)
        if location == None:
            pt.moveTo(151,521,1)
            pt.scroll(-100)
        else:
            pt.moveTo(location,duration=1)
            print(location)
            pt.click()
# Out:
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# c:\Users\purusp\OneDrive - adidas\Adidas\3. Learning\8. Python\1. Pyautogui\pyautogui_learning2.ipynb Cell 10 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/purusp/OneDrive%20-%20adidas/Adidas/3.%20Learning/8.%20Python/1.%20Pyautogui/pyautogui_learning2.ipynb#X11sZmlsZQ%3D%3D?line=17'>18</a> location = pt.locateCenterOnScreen("pl.PNG", confidence=0.8)
#      <a href='vscode-notebook-cell:/c%3A/Users/purusp/OneDrive%20-%20adidas/Adidas/3.%20Learning/8.%20Python/1.%20Pyautogui/pyautogui_learning2.ipynb#X11sZmlsZQ%3D%3D?line=18'>19</a> if location == None:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/purusp/OneDrive%20-%20adidas/Adidas/3.%20Learning/8.%20Python/1.%20Pyautogui/pyautogui_learning2.ipynb#X11sZmlsZQ%3D%3D?line=19'>20</a>     pt.moveTo(151,521,1)
# ...

# %%
test = pt.prompt(text="",title="test")

url = "https://app.powerbi.com/groups/me/apps/b69dcb06-a0bc-4351-a569-06fa7dc97b0c/reports/2992eb5e-0573-4f93-b372-0bbe35674315/ReportSection96b95aa4b0b901409708?experience=power-bi"
webbrowser.open(url)

export = pt.locateCenterOnScreen("export.PNG", confidence=0.9)
while export == None:
    export = pt.locateCenterOnScreen("export.PNG", confidence=0.8)
    print(export)

time.sleep(1)
location = pt.locateCenterOnScreen("pl.PNG", confidence=0.8)
while location == None:
    if location == None:
        pt.moveTo(151,521,1)
        pt.scroll(-30)

    
pt.moveTo(location,duration=1)
print(location)
pt.click()

pt.scroll(-50)

time.sleep(1)
location = pt.locateCenterOnScreen("pl by segment.PNG", confidence=0.9)
pt.moveTo(location,duration=1)
pt.click()
# Out:
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# c:\Users\purusp\OneDrive - adidas\Adidas\3. Learning\8. Python\1. Pyautogui\pyautogui_learning2.ipynb Cell 9 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/purusp/OneDrive%20-%20adidas/Adidas/3.%20Learning/8.%20Python/1.%20Pyautogui/pyautogui_learning2.ipynb#W6sZmlsZQ%3D%3D?line=11'>12</a> while location == None:
#      <a href='vscode-notebook-cell:/c%3A/Users/purusp/OneDrive%20-%20adidas/Adidas/3.%20Learning/8.%20Python/1.%20Pyautogui/pyautogui_learning2.ipynb#W6sZmlsZQ%3D%3D?line=12'>13</a>     if location == None:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/purusp/OneDrive%20-%20adidas/Adidas/3.%20Learning/8.%20Python/1.%20Pyautogui/pyautogui_learning2.ipynb#W6sZmlsZQ%3D%3D?line=13'>14</a>         pt.moveTo(151,521,1)
# ...
